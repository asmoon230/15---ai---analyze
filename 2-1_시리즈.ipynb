# %%
#시리즈

## 외부라이브러리 pandas 설치
## pip install pandas


## 라이브러리 불러오기
import pandas as pd


dict_data = {
    "a" : 1,
    "b" : 2,
    "c" : 3,

}

sr = pd.Series(dict_data)

print(type(sr))
# Out:
# <class 'pandas.Series'>

# %%
print(sr)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
## 인덱스 배열
## Series객체.index 

print(sr.index)
# Out:
# Index(['a', 'b', 'c'], dtype='str')

# %%
## 데이터 값 배열
## Serieso객체.values

print(sr.values)
# Out:
# [1 2 3]

# %%
## 시리즈 인덱스

import pandas as pd

list_data = ["2019-01-01", 3.14, "ABC", 100, True]

sr = pd.Series(list_data)

print(sr)
# Out:
# 0    2019-01-01
# 1          3.14
# 2           ABC
# 3           100
# 4          True
# dtype: object

# %%
## 인덱스

## values
 
print(sr.index)
print(sr.values)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# ['2019-01-01' 3.14 'ABC' 100 True]

# %%
## 시리즈 객체의 데이터 타입 확인

print(sr.dtype)
# Out:
# object

# %%
## 원소의 개수 확인하기

print(len(sr))
# Out:
# 5

# %%
## 배열의 형태

sr.shape
# Out:
# (5,)

# %%
## 데이터의 구조의 차원수
## ndim 속성
print(sr.ndim)
# Out:
# 1

# %%
# 원소 선택

import pandas as pd

tup_data = ("영인", "2010-05-01", "여", True)
sr = pd.Series(tup_data,index = ["이름","생년월일","성별","학생여부"])

print(sr)
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object

# %%
# 원소선택

# print(sr[0])
sr["이름"]
# Out:
# '영인'

# %%
sr[["이름","생년월일"]]
# Out:
# 이름              영인
# 생년월일    2010-05-01
# dtype: object

# %%
print(sr)
print(sr[1:2])
print(sr["생년월일":"성별"])
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object
# 생년월일    2010-05-01
# dtype: object
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
# 시리즈 객체를 만드는 특수한 방법

import pandas as pd

a = pd.Series()

# %%
print(a)
# Out:
# Series([], dtype: object)

# %%
b = pd.Series(5)
print(b)
# Out:
# 0    5
# dtype: int64

# %%
c = pd.Series("a", index = ["a","b","c"])
print(c)
# Out:
# a    a
# b    a
# c    a
# dtype: str

# %%
# 데이터 프레임

## 딕셔너리 -> 데이터프레임으로 변환
## pandas.DataFrame(딕셔너리)

import pandas as pd

dict_data = {
    "c0" : [1, 2, 3],
    "c1" : [4, 5, 6],
    "c2" : [7, 8, 9],
    "c3" : [10, 11, 12],
    "c4" : [13, 14, 15]
}

## 시리즈로 변환한 값
sr = pd.Series(dict_data)
print(sr)

## 데이터프레임으로 변환한값
df = pd.DataFrame(dict_data)
print(df)
# Out:
# c0       [1, 2, 3]
# c1       [4, 5, 6]
# c2       [7, 8, 9]
# c3    [10, 11, 12]
# c4    [13, 14, 15]
# dtype: object
#    c0  c1  c2  c3  c4
# 0   1   4   7  10  13
# 1   2   5   8  11  14
# 2   3   6   9  12  15

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
# 행 인덱스 / 열 이름 설정

import pandas as pd

list_data = [
    [15, "남", "덕영중"],
    [17, "여", "수리중"]
]

df = pd.DataFrame(list_data, index=["준서", "예은"], columns=["나이", "성별", "학교"])

print(df)
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
## 인덱스 명 가져오기

print(df.index)


## 열 이름 가져오기
print(df.columns)
# Out:
# Index(['준서', '예은'], dtype='str')
# Index(['나이', '성별', '학교'], dtype='str')

# %%
print(df)


df.index = ["학생 1", "학생 2"]
df.columns = ["연령", "남여", "소속"]

print(df)
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중
#       연령 남여   소속
# 학생 1  15  남  덕영중
# 학생 2  17  여  수리중

# %%
import pandas as pd

list_data = [
    [15, "남", "덕영중"],
    [17, "여", "수리중"]
]

df = pd.DataFrame(list_data, index=["준서", "예은"], columns=["나이", "성별", "학교"])
print(df)
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
df = df.rename(columns={
    "나이" : "연령",
    "성별" : "남여",
    "학교" : "소속"
})

print(df)
# Out:
#     연령 남여   소속
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
df = df.rename(index={
    "준서" : "학생1",
    "예은" : "학생2"
})
print(df)
# Out:
#      연령 남여   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
# 행/ 열 삭제
## 행 삭제-->> DateFrame객체.drop(행인덱스 또는 배열, axis = 0 또는 axis ="index")
## 열 삭제-->> DateFrame객체.drop(열인덱스 또는 배열, axis = 1 또는 axis ="columns")

# %%
import pandas as pd

exam_data = {
    "수학" : [90, 80, 70],
    "영어" : [98, 89, 95],
    "음악" : [95, 95, 100],
    "체육" : [100, 90, 90]
}

df = pd.DataFrame(exam_data, index = ["서준","우현", "인아"])
print(df)
# Out:
#     수학  영어   음악   체육
# 서준  90  98   95  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df2 = df.copy()
df2 = df2.drop("우현")
print(df2)
# Out:
#     수학  영어   음악   체육
# 서준  90  98   95  100
# 인아  70  95  100   90

# %%
df3 = df.copy()

df3
# Out:
#     수학  영어   음악   체육
# 서준  90  98   95  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df3 = df3.drop("영어",axis = 1)

# %%
df3
# Out:
#     수학   음악   체육
# 서준  90   95  100
# 우현  80   95   90
# 인아  70  100   90

# %%
df3 = df.copy()
df3
# Out:
#     수학  영어   음악   체육
# 서준  90  98   95  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df3.drop(["영어", "음악"], axis = 1)
# Out:
#     수학   체육
# 서준  90  100
# 우현  80   90
# 인아  70   90

# %%
df4 = df.copy()
df4
# Out:
#     수학  영어   음악   체육
# 서준  90  98   95  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df4 = df4.drop(["음악", "영어"],axis = "columns")

# %%
df4
# Out:
#     수학   체육
# 서준  90  100
# 우현  80   90
# 인아  70   90

# %%
df5 = df.copy()
df5 = df5.drop(columns=["수학"])

# %%
df5
# Out:
#     영어   음악   체육
# 서준  98   95  100
# 우현  89   95   90
# 인아  95  100   90

# %%
# 행선택
## loc 인덱서

print(df)
print()
labell = df.loc["서준"]
position = df.iloc[0]

print(labell)
print()
print(position)
# Out:
#     수학  영어   음악   체육
# 서준  90  98   95  100
# 우현  80  89   95   90
# 인아  70  95  100   90
#
# 수학     90
# 영어     98
# 음악     95
# 체육    100
# Name: 서준, dtype: int64
#
# 수학     90
# 영어     98
# 음악     95
# 체육    100
# Name: 서준, dtype: int64

# %%
label2 = df.loc[["서준", "우현"]]
position2 = df.iloc[[0,1]]

print(label2)
print()
print(position2)
# Out:
#     수학  영어  음악   체육
# 서준  90  98  95  100
# 우현  80  89  95   90
#
#     수학  영어  음악   체육
# 서준  90  98  95  100
# 우현  80  89  95   90

# %%
# 열 선택

import pandas as pd

exam_data = {
    "이름" : ["서준", "우현", "인아"],    
    "수학" : [90, 80, 70],
    "영어" : [98, 89, 95],
    "음악" : [95, 95, 100],
    "체육" : [100, 90, 90]
}


df = pd.DataFrame(exam_data)
print(type(df))
df
# Out:
# <class 'pandas.DataFrame'>
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
# type(df["수학"]) -> Serise 타입
math1 = df["수학"]

# %%
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
print(df.영어)
print(type(df.영어))
# Out:
# 0    98
# 1    89
# 2    95
# Name: 영어, dtype: int64
# <class 'pandas.Series'>

# %%
music_gym = df[["음악", "체육"]]
print(type(music_gym))
# Out:
# <class 'pandas.DataFrame'>

# %%
math1 = df["수학"]
math2 = df[["수학"]]


print(math1)
print(math2)
print()
print(type(math1))
print(type(math2))
# Out:
# 0    90
# 1    80
# 2    70
# Name: 수학, dtype: int64
#    수학
# 0  90
# 1  80
# 2  70
#
# <class 'pandas.Series'>
# <class 'pandas.DataFrame'>

# %%
## 범위 슬라이싱
## 데이터프레임 객체.iloc[시작인덱스 : 끝인덱스 : 간격]

df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
df.iloc[0]
# Out:
# 이름     서준
# 수학     90
# 영어     98
# 음악     95
# 체육    100
# Name: 0, dtype: object

# %%
df.iloc[::2]
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 2  인아  70  95  100   90

# %%
df[0:2]
# Out:
#    이름  수학  영어  음악   체육
# 0  서준  90  98  95  100
# 1  우현  80  89  95   90

# %%
df[:3]
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
df.iloc[:3:2]
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 2  인아  70  95  100   90

# %%
df.iloc[::-1]
# Out:
#    이름  수학  영어   음악   체육
# 2  인아  70  95  100   90
# 1  우현  80  89   95   90
# 0  서준  90  98   95  100

# %%
## 원소선택
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]

]

matrix[1][1]
# Out:
# 5

# %%
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
import pandas as pd

exam_data = {
    "이름" : ["서준", "우현", "인아"],    
    "수학" : [90, 80, 70],
    "영어" : [98, 89, 95],
    "음악" : [95, 95, 100],
    "체육" : [100, 90, 90]
}


df = pd.DataFrame(exam_data)
df = df.set_index("이름")
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   95  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
## 인덱스이름: DF객체.loc[행인덱스, 열이름]
## 정수위치인덱스: DF객체.iloc[행번호, 열번호]

print(df.loc["서준", "음악"])
print(df.iloc[0,2])
# Out:
# 95
# 95

# %%
# 열추가
# DF객체["추가하려는 열이름"] = 데이터값

exam_data = {
    "이름" : ["서준", "우현", "인아"],    
    "수학" : [90, 80, 70],
    "영어" : [98, 89, 95],
    "음악" : [95, 95, 100],
    "체육" : [100, 90, 90]
}

df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
df["국어"] = 80
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   95  100  80
# 1  우현  80  89   95   90  80
# 2  인아  70  95  100   90  80

# %%
df["미술"] = [80, 90, 100]
df
# Out:
#    이름  수학  영어   음악   체육  국어   미술
# 0  서준  90  98   95  100  80   80
# 1  우현  80  89   95   90  80   90
# 2  인아  70  95  100   90  80  100

# %%
# 행 추가
## DF객체.loc["새로운행이름"] = 데이터 값 또는 배열

exam_data = {
    "이름" : ["서준", "우현", "인아"],    
    "수학" : [90, 80, 70],
    "영어" : [98, 89, 95],
    "음악" : [95, 95, 100],
    "체육" : [100, 90, 90]
}

df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   95  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
df.loc[2]
df.loc[4] = ["술의", 20 , 40 , 10, 40]

# %%
df
# Out:
#     이름   수학   영어   음악   체육
# 0   서준   90   98   95  100
# 1   우현   80   89   95   90
# 2   인아   70   95  100   90
# 3  100  100  100  100  100
# 4   술의   20   40   10   40

# %%
df.loc["행5"] = df.loc[0]
df
# Out:
#      이름   수학   영어   음악   체육
# 0    서준   90   98   95  100
# 1    우현   80   89   95   90
# 2    인아   70   95  100   90
# 3   100  100  100  100  100
# 4    술의   20   40   10   40
# 행5   서준   90   98   95  100

# %%
df.loc["행6"] = df.loc[3]
df
# Out:
#      이름   수학   영어   음악   체육
# 0    서준   90   98   95  100
# 1    우현   80   89   95   90
# 2    인아   70   95  100   90
# 3   100  100  100  100  100
# 4    술의   20   40   10   40
# 행5   서준   90   98   95  100
# 행6  100  100  100  100  100

# %%
## 원소 값 변경

exam_data = {
    "이름" : ["서준", "우현", "인아"],    
    "수학" : [90, 80, 70],
    "영어" : [98, 89, 95],
    "음악" : [95, 95, 100],
    "체육" : [100, 90, 90]
}

df = pd.DataFrame(exam_data)

# %%
df = df.set_index("이름")

# %%
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   95  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df.iloc[0,0]
# Out:
# np.int64(90)

# %%
df.loc["서준","수학"]
# Out:
# np.int64(90)

# %%
df.iloc[0][3] = 80
# Out:
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_6460\3723863810.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df.iloc[0][3] = 80

# %%
df.loc["서준"]["체육"] = 90
# Out:
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_6460\1329147877.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df.loc["서준"]["체육"] = 90

# %%
## 행과 열 바꾸기
## DF객체.transpose()
## DF객체.T

exam_data = {
    "이름" : ["서준", "우현", "인아"],    
    "수학" : [90, 80, 70],
    "영어" : [98, 89, 95],
    "음악" : [95, 95, 100],
    "체육" : [100, 90, 90]
}

df = pd.DataFrame(exam_data)

# %%
print(df.T)
df.transpose()
# Out:
#       0   1    2
# 이름   서준  우현   인아
# 수학   90  80   70
# 영어   98  89   95
# 음악   95  95  100
# 체육  100  90   90
#       0   1    2
# 이름   서준  우현   인아
# 수학   90  80   70
# 영어   98  89   95
# 음악   95  95  100
# 체육  100  90   90
