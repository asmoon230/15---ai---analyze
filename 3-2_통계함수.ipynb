# %%
import pandas as pd

df = pd.read_csv("./data/auto-mpg.csv", header=None)

df.columns = [
    "mpg", "cylinders", "displacement", "horsepower","weight","acceleration","model year","origin","name"
]

df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.mean()
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:14473, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14392 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14393 def mean(
#   14394     self,
#    (...)  14398     **kwargs,
#   14399 ) -> Series | Any:
#   14400     """
#   14401     Return the mean of the values over the requested axis.
#   14402
#    (...)  14471     dtype: float64
#   14472     """
# > 14473     result = super().mean(
#   14474         axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14475     )
#   14476     if isinstance(result, Series):
#   14477         result = result.__finalize__(self, method="mean")
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11823 def mean(
#   11824     self,
#   11825     *,
#    (...)  11829     **kwargs,
#   11830 ) -> Series | float:
# > 11831     return self._stat_function(
#   11832         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833     )
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:13633, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13629     df = df.T
#   13631 # After possibly _get_data and transposing, we are now in the
#   13632 #  simple case where we can use BlockManager.reduce
# > 13633 res = df._mgr.reduce(blk_func)
#   13634 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13635 out.name = None
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:1681, in BlockManager.reduce(self, func)
#    1678 # If 2D, we assume that we're operating column-wise
#    1679 assert self.ndim == 2
# -> 1681 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1682 index = default_index(1)  # placeholder
#    1683 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:13561, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13559     if not is_1d_only_ea_dtype(values.dtype):
#   13560         return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 13561     return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13562 else:
#   13563     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\string_arrow.py:563, in ArrowStringArray._reduce(self, name, skipna, keepdims, **kwargs)
#     561     result = self._reduce_calc(name, skipna=skipna, keepdims=keepdims, **kwargs)
#     562 else:
# --> 563     raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#     565 if name in ("argmin", "argmax") and isinstance(result, pa.Array):
#     566     return self._convert_int_result(result)
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %%
df.mean(numeric_only = True)
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model year        76.010050
# origin             1.572864
# dtype: float64

# %%
df["mpg"].mean()
# Out:
# np.float64(23.514572864321607)

# %%
print(round(df["mpg"].mean(),2))
print(df["mpg"].mean().round(2))
# Out:
# 23.51
# 23.51

# %%
# 중앙값

print(df.median(numeric_only=True))
print(df["mpg"].median())
# Out:
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# weight          2803.5
# acceleration      15.5
# model year        76.0
# origin             1.0
# dtype: float64
# 23.0

# %%
# 최댓값

df.max(numeric_only=True)

# 최솟값
df.min(numeric_only=True)
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# weight          1613.0
# acceleration       8.0
# model year        70.0
# origin             1.0
# dtype: float64

# %%
# 표준편차
 
print(df.std(numeric_only=True))
print(df["mpg"].std())
# Out:
# mpg               7.815984
# cylinders         1.701004
# displacement    104.269838
# weight          846.841774
# acceleration      2.757689
# model year        3.697627
# origin            0.802055
# dtype: float64
# 7.815984312565782

# %%
# 상관계수

print(df.corr(numeric_only=True))
print(df[["mpg", "weight"]].corr())
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000
